# %% [markdown]
# # Word / Sentence Matching

# %%
import difflib
import re

# %%
def text_cleanUp(input_string):
    # Replace commas with spaces
    step1 = input_string.replace(',', ' ')

    step2 = re.sub(r'[^a-zA-Z0-9\s]', '', step1)

    # Replace multiple spaces with a single space
    step3 = re.sub(r'\s+', ' ', step2)

    return step3

# %%
def compare_statements(statement1, statement2):

    if statement1 is None:
      statement1 = ''
    if statement2 is None:
      statement2 = ''
    # Tokenize statements into words
    words1 = text_cleanUp(statement1).split()
    words2 = text_cleanUp(statement2).split()

    # Calculate matching ratio using SequenceMatcher
    matcher = difflib.SequenceMatcher(None, words1, words2)
    matching_ratio = matcher.ratio()
    matched_words1 = []
    matched_words2 = []
    # Get the list of matching and mismatching words
    matching_words = [word for word in matcher.get_matching_blocks()]
    for matching_words_row in matching_words:
      matched_words1.append(words1[matching_words_row[0]:matching_words_row[0] + matching_words_row[2]])
      matched_words2.append(words2[matching_words_row[1]:matching_words_row[1] + matching_words_row[2]])

    matched_words1 = [word for sublist in matched_words1 for word in sublist]
    matched_words2 = [word for sublist in matched_words2 for word in sublist]


    mismatched_words1 = list(set(words1) - set(matched_words1))
    mismatched_words2 = list(set(words2) - set(matched_words2))

    return matching_ratio, mismatched_words1, mismatched_words2

# %%
if __name__ == '__main__':
  # Example usage:
  statement1 = 'The quick brown fox jumps over the lazy dog.'
  statement2 = 'A quick fox jumps over a lazy dog.'

  matching_ratio, mismatched_words1, mismatched_words2 = compare_statements(statement1, statement2)

  print(f"Matching Ratio: {matching_ratio:.2%}")
  print("Mismatched Words in Statement 1:", mismatched_words1)
  print("Mismatched Words in Statement 2:", mismatched_words2)
# Out:
# Matching Ratio: 70.59%
# Mismatched Words in Statement 1: ['brown', 'the', 'The']
# Mismatched Words in Statement 2: ['A', 'a']

# %%
if __name__ == '__main__':
  statement1 = 'DESCRIBE THE BASIC CONCEPTSY COMPONENTSS PRINCIPLESS ANTD DEVICES DF ETHERNET NETWORKS ,DESCRIBE THE ROLE OF NETWORK DEVICES AND DATA COMMUNICATIONS PROTOCOL MODAL LAYERS ,DESIGN AND CALCULATE IPVAS IPY6 SUBNET ADDRESSING SCHEMES TO MEET BUSINESS NEEDS ,APPLY NETWORKING PRINCIPLES TO IESIGNS DOCUMENT AND CABLE I BASIC ROUTER AND SWITCHHBASED ETHERNET NETWORK TO MEET BUSINESS REQUIREMENTS ,APPLY NETWORK OPERATING SYSTEM COMMANDS TO CONFIGURES VERIFYS TESTS AND TROUBLESHOOT ROUTERSS SWITCHEST AND HOST DEVICES '
  statement2 = 'DESCRIBE THE BASIC CONCEPTS , COMPONENTS , PRINCIPLES , AND DEVICES OF ETHERNET NETWORKS ,DESCRIBE THE ROLE OF NETWORK DEVICES AND DATA COMMUNICATIONS PROTOCOL MODEL LAYERS ,DESIGN AND CALCULATE IPV4 , IPV6 SUBNET ADDRESSING SCHEMES TO MEET BUSINESS NEEDS ,APPLY NETWORKING PRINCIPLES TO DESIGN , DOCUMENT AND CABLE A BASIC ROUTER AND SWITCH -BASED ETHERNET NETWORK TO MEET BUSINESS REQUIREMENTS ,APPLY NETWORK OPERATING SYSTEM COMMANDS T O CONFIGURE , VERIFY , TEST , AND TROUBLESHOOT ROUTERS , SWITCHES , AND HOST DEVICES '

  matching_ratio, mismatched_words1, mismatched_words2 = compare_statements(statement1, statement2)

  print(f"Matching Ratio: {matching_ratio:.2%}")
  print("Mismatched Words in Statement 1:", mismatched_words1)
  print("Mismatched Words in Statement 2:", mismatched_words2)
# Out:
# Matching Ratio: 74.65%
# Mismatched Words in Statement 1: ['TESTS', 'SWITCHEST', 'CONFIGURES', 'IESIGNS', 'I', 'COMPONENTSS', 'SWITCHHBASED', 'ROUTERSS', 'VERIFYS', 'MODAL', 'PRINCIPLESS', 'DF', 'CONCEPTSY', 'ANTD', 'IPVAS', 'IPY6']
# Mismatched Words in Statement 2: ['IPV6', 'BASED', 'A', 'SWITCHES', 'VERIFY', 'O', 'T', 'MODEL', 'COMPONENTS', 'ROUTERS', 'TEST', 'CONCEPTS', 'IPV4', 'CONFIGURE', 'SWITCH']

# %%
if __name__ == '__main__':
  statement1 = 'DESCRIBE THE BASIC CONCEPTS , COMPONENTS , PRINCIPLES , AND DEVICES OF ETHERNET NETWORKS'
  statement2 = 'DESCRIBE THE BASIC CONCEPTSY COMPONENTSS PRINCIPLESS ANTD DEVICES DF ETHERNET NETWORKS'

  matching_ratio, mismatched_words1, mismatched_words2 = compare_statements(statement1, statement2)

  print(f"Matching Ratio: {matching_ratio:.2%}")
  print("Mismatched Words in Statement 1:", mismatched_words1)
  print("Mismatched Words in Statement 2:", mismatched_words2)

  statement1 = 'DESCRIBE THE ROLE OF NETWORK DEVICES AND DATA COMMUNICATIONS PROTOCOL MODEL LAYERS'
  statement2 = 'DESCRIBE THE ROLE OF NETWORK DEVICES AND DATA COMMUNICATIONS PROTOCOL MODAL LAYERS'

  matching_ratio, mismatched_words1, mismatched_words2 = compare_statements(statement1, statement2)

  print(f"Matching Ratio: {matching_ratio:.2%}")
  print("Mismatched Words in Statement 1:", mismatched_words1)
  print("Mismatched Words in Statement 2:", mismatched_words2)


  statement1 = 'DESIGN AND CALCULATE IPV4 , IPV6 SUBNET ADDRESSING SCHEMES TO MEET BUSINESS NEEDS'
  statement2 = 'DESIGN AND CALCULATE IPVAS IPY6 SUBNET ADDRESSING SCHEMES TO MEET BUSINESS NEEDS'

  matching_ratio, mismatched_words1, mismatched_words2 = compare_statements(statement1, statement2)

  print(f"Matching Ratio: {matching_ratio:.2%}")
  print("Mismatched Words in Statement 1:", mismatched_words1)
  print("Mismatched Words in Statement 2:", mismatched_words2)



  statement1 = 'APPLY NETWORKING PRINCIPLES TO DESIGN , DOCUMENT AND CABLE A BASIC ROUTER AND SWITCH -BASED ETHERNET NETWORK TO MEET BUSINESS REQUIREMENTS'
  statement2 = 'APPLY NETWORKING PRINCIPLES TO IESIGNS DOCUMENT AND CABLE I BASIC ROUTER AND SWITCHHBASED ETHERNET NETWORK TO MEET BUSINESS REQUIREMENTS'

  matching_ratio, mismatched_words1, mismatched_words2 = compare_statements(statement1, statement2)

  print(f"Matching Ratio: {matching_ratio:.2%}")
  print("Mismatched Words in Statement 1:", mismatched_words1)
  print("Mismatched Words in Statement 2:", mismatched_words2)


  statement1 = 'APPLY NETWORK OPERATING SYSTEM COMMANDS T O CONFIGURE , VERIFY , TEST , AND TROUBLESHOOT ROUTERS , SWITCHES , AND HOST DEVICES'
  statement2 = 'APPLY NETWORK OPERATING SYSTEM COMMANDS TO CONFIGURES VERIFYS TESTS AND TROUBLESHOOT ROUTERSS SWITCHEST AND HOST DEVICES'

  matching_ratio, mismatched_words1, mismatched_words2 = compare_statements(statement1, statement2)

  print(f"Matching Ratio: {matching_ratio:.2%}")
  print("Mismatched Words in Statement 1:", mismatched_words1)
  print("Mismatched Words in Statement 2:", mismatched_words2)
# Out:
# Matching Ratio: 54.55%
# Mismatched Words in Statement 1: ['OF', 'AND', 'COMPONENTS', 'CONCEPTS', 'PRINCIPLES']
# Mismatched Words in Statement 2: ['COMPONENTSS', 'PRINCIPLESS', 'DF', 'ANTD', 'CONCEPTSY']
# Matching Ratio: 91.67%
# Mismatched Words in Statement 1: ['MODEL']
# Mismatched Words in Statement 2: ['MODAL']
# Matching Ratio: 83.33%
# Mismatched Words in Statement 1: ['IPV4', 'IPV6']
# Mismatched Words in Statement 2: ['IPVAS', 'IPY6']
# Matching Ratio: 82.05%
# Mismatched Words in Statement 1: ['DESIGN', 'BASED', 'A', 'SWITCH']
# Mismatched Words in Statement 2: ['I', 'IESIGNS', 'SWITCHHBASED']
# Matching Ratio: 60.61%
# Mismatched Words in Statement 1: ['VERIFY', 'SWITCHES', 'O', 'T', 'TEST', 'ROUTERS', 'CONFIGURE']
# Mismatched Words in Statement 2: ['TESTS', 'SWITCHEST', 'ROUTERSS', 'CONFIGURES', 'TO', 'VERIFYS']

# %%
if __name__ == '__main__':


  statement1 = 'HELLO'
  statement2 = 'HELLOW'

  matching_ratio, mismatched_words1, mismatched_words2 = compare_statements(statement1, statement2)

  print(f"Matching Ratio: {matching_ratio:.2%}")
  print("Mismatched Words in Statement 1:", mismatched_words1)
  print("Mismatched Words in Statement 2:", mismatched_words2)

  statement1 = 'FINE WORD'
  statement2 = 'WORD'

  matching_ratio, mismatched_words1, mismatched_words2 = compare_statements(statement1, statement2)

  print(f"Matching Ratio: {matching_ratio:.2%}")
  print("Mismatched Words in Statement 1:", mismatched_words1)
  print("Mismatched Words in Statement 2:", mismatched_words2)


  statement1 = 'FINE WORD'
  statement2 = 'FINE WORDS'

  matching_ratio, mismatched_words1, mismatched_words2 = compare_statements(statement1, statement2)

  print(f"Matching Ratio: {matching_ratio:.2%}")
  print("Mismatched Words in Statement 1:", mismatched_words1)
  print("Mismatched Words in Statement 2:", mismatched_words2)



  statement1 = 'FINE WORDS'
  statement2 = 'FINE WORD'

  matching_ratio, mismatched_words1, mismatched_words2 = compare_statements(statement1, statement2)

  print(f"Matching Ratio: {matching_ratio:.2%}")
  print("Mismatched Words in Statement 1:", mismatched_words1)
  print("Mismatched Words in Statement 2:", mismatched_words2)


  statement1 = 'FINE WORD'
  statement2 = 'FINE TEST'

  matching_ratio, mismatched_words1, mismatched_words2 = compare_statements(statement1, statement2)

  print(f"Matching Ratio: {matching_ratio:.2%}")
  print("Mismatched Words in Statement 1:", mismatched_words1)
  print("Mismatched Words in Statement 2:", mismatched_words2)
# Out:
# Matching Ratio: 0.00%
# Mismatched Words in Statement 1: ['HELLO']
# Mismatched Words in Statement 2: ['HELLOW']
# Matching Ratio: 66.67%
# Mismatched Words in Statement 1: ['FINE']
# Mismatched Words in Statement 2: []
# Matching Ratio: 50.00%
# Mismatched Words in Statement 1: ['WORD']
# Mismatched Words in Statement 2: ['WORDS']
# Matching Ratio: 50.00%
# Mismatched Words in Statement 1: ['WORDS']
# Mismatched Words in Statement 2: ['WORD']
# Matching Ratio: 50.00%
# Mismatched Words in Statement 1: ['WORD']
# Mismatched Words in Statement 2: ['TEST']

# %%
  statement1 = 'FINE WORD'
  statement2 = 'FINE WORD '

  matching_ratio, mismatched_words1, mismatched_words2 = compare_statements(statement1, statement2)

  print(f"Matching Ratio: {matching_ratio:.2%}")
  print("Mismatched Words in Statement 1:", mismatched_words1)
  print("Mismatched Words in Statement 2:", mismatched_words2)
# Out:
# Matching Ratio: 100.00%
# Mismatched Words in Statement 1: []
# Mismatched Words in Statement 2: []

# %%
# Example usage:
input_string = 'IDENTIFY , SELECT , INSTALL , CONFIGURE , AND TROUBLESHOOT HARDWARE DEVICES AND SOFTWARE APPLICATIONS,EVALUATE THE DIFFERENT COMPONENTS OF IT HARDWARE DEVICES , INCLUDING PC , LAPTOP , MOTHERBOARD , POWER SUPPLY , AND STORAGE,APPLY TROUBLESHOOTING KNOWLEDGE AND TECHNIQUES IN CONFIGURING PERIPHERAL CONNECTIONS IN A SECURE MANNER TO MEET SECURITY AND ORGANISATIONAL REQUIREMENTS'
output_string = text_cleanUp(input_string)

print(output_string)
# Out:
# IDENTIFY SELECT INSTALL CONFIGURE AND TROUBLESHOOT HARDWARE DEVICES AND SOFTWARE APPLICATIONS EVALUATE THE DIFFERENT COMPONENTS OF IT HARDWARE DEVICES INCLUDING PC LAPTOP MOTHERBOARD POWER SUPPLY AND STORAGE APPLY TROUBLESHOOTING KNOWLEDGE AND TECHNIQUES IN CONFIGURING PERIPHERAL CONNECTIONS IN A SECURE MANNER TO MEET SECURITY AND ORGANISATIONAL REQUIREMENTS
